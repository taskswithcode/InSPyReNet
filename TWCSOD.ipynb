# %% [markdown]
# <a href="https://colab.research.google.com/github/taskswithcode/InSPyReNet/blob/main/TWCSOD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Notebook to reproduce results of Salient Object detection**

# %% [markdown]
# ## 1. Check GPU is available

# %%
# !nvidia-smi

# %% [markdown]
# ## 2. Download the tar file containing original repository, environment snapshot, and required models

# %%
# !gdown 1wdiXVpTkVcW5MhB8_5JtqpIPKWA2wUTy

# %%
# !mv s3cfg /root/.s3cfg

# %%
# !apt-get install s3cmd

# %%
# !s3cmd ls s3://repos

# %%
# !git clone https://github.com/taskswithcode/InSPyReNet.git

# %%
cd InSPyReNet
# Out:
# /content/InSPyReNet

# %%
# !ls

# %%
# !s3cmd get s3://repos/salient_object_detection_env.tar

# %% [markdown]
# ## 3. Extract from the tar file and change working directory

# %%
# !tar xvf salient_object_detection_env.tar

# %%
# !ls

# %% [markdown]
# ## 4. Set up local environment

# %%
# !./twc_setup.sh

# %%
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image
from IPython.display import display # to display imag

# %% [markdown]
# ## 5a. Run sample tests within the environment, starting with replicating tests from original repository

# %%
!(source conda_envs/bin/activate; ./twc_test.sh twc_samples/sample1.png results map)

# %%
!(source conda_envs/bin/activate; ./twc_test.sh twc_samples/sample5.png results blur)

# %%
pil_im = Image.open('twc_samples/sample1.png')
display(pil_im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=384x384 at 0x7F1AD9B9B3D0>

# %%
pil_im = Image.open('results/sample1.png')
display(pil_im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=384x384 at 0x7F1AD9ABF590>

# %%
pil_im = Image.open('twc_samples/sample5.png')
display(pil_im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7F1AD9A93C90>

# %%
pil_im = Image.open('results/sample5.png')
display(pil_im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7F1AD13516D0>

# %%
!(source conda_envs/bin/activate; ./twc_test.sh twc_samples/sample2.png results blur)

# %%
pil_im = Image.open('twc_samples/sample2.png')
display(pil_im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=384x384 at 0x7F1AD134E750>

# %%
pil_im = Image.open('results/sample2.png')
display(pil_im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=384x384 at 0x7F1AD134CE50>

# %%
!(source conda_envs/bin/activate; ./twc_test.sh twc_samples/dog_running.mp4)
